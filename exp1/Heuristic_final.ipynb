# %%
import os
import csv
import pdb
import math
import time 
import pickle
import pickle
import random
import warnings
import datetime 
import collections
import numpy as np 
import pandas as pd  
import xgboost as xgb
import networkx as nx
from tqdm.notebook import tqdm
import matplotlib.pylab as plt 
from matplotlib import rcParams   
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import f1_score
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
import time
from pandas import read_hdf

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data_path = "gdrive/My Drive/Major Project 8th sem/Major Project"

# %%
train_emb = read_hdf(data_path + '/fea_sample/storage_sample_stage4.h5', 'train_df',mode='r')
test_emb = read_hdf(data_path + '/fea_sample/storage_sample_stage4.h5', 'test_df',mode='r')

# %%
train_y = train_emb.link
test_y = test_emb.link

# %%
train_emb.drop(['src', 'dest','link'],axis=1,inplace=True)
test_emb.drop(['src', 'dest','link'],axis=1,inplace=True)

# %%
clf = XGBClassifier(max_depth=7, n_estimators=100, n_jobs=-1,
              random_state=25)
start = time.time()
clf.fit(train_emb, train_y)
print("Time taken for XGB fit = ", time.time() - start)
start = time.time()
train_sc = f1_score(train_y,clf.predict(train_emb))
print("Time taken for train data precition = ", time.time() - start)
start = time.time()
test_sc = f1_score(test_y,clf.predict(test_emb))
print("Time taken for test data precition = ", time.time() - start)
print('Train Score',train_sc,'test Score',test_sc)
# Out:
# Time taken for XGB fit =  509.01891231536865
# Time taken for train data precition =  5.36719536781311
# Time taken for test data precition =  0.5977840423583984
# Train Score 0.983029655226594 test Score 0.9458179808400884

# %%
clf = RandomForestClassifier(max_depth=12, n_estimators=100, n_jobs=-1,
              random_state=25)
start = time.time()
clf.fit(train_emb, train_y)
print("Time taken for RandomForest fit = ", time.time() - start)
start = time.time()
train_sc = f1_score(train_y,clf.predict(train_emb))
print("Time taken for train data precition = ", time.time() - start)
start = time.time()
test_sc = f1_score(test_y,clf.predict(test_emb))
print("Time taken for test data precition = ", time.time() - start)
print('Train Score',train_sc,'test Score',test_sc)
# Out:
# Time taken for RandomForest fit =  309.246253490448
# Time taken for train data precition =  11.299275875091553
# Time taken for test data precition =  1.2950026988983154
# Train Score 0.9771341261464953 test Score 0.9465713006860139

# %%
clf = LGBMClassifier(boosting_type='gbdt', num_leaves=31, max_depth=-1, learning_rate=0.1, n_estimators=100, subsample_for_bin=200000, 
                     objective=None, class_weight=None, min_split_gain=0.0, min_child_weight=0.001, min_child_samples=20, subsample=1.0, 
                     subsample_freq=0, colsample_bytree=1.0, reg_alpha=0.0, reg_lambda=0.0, random_state=None, n_jobs=- 1, importance_type='split')
start = time.time()
clf.fit(train_emb, train_y)
print("Time taken for LGBM fit = ", time.time() - start)
start = time.time()
train_sc = f1_score(train_y,clf.predict(train_emb))
print("Time taken for train data precition = ", time.time() - start)
start = time.time()
test_sc = f1_score(test_y,clf.predict(test_emb))
print("Time taken for test data precition = ", time.time() - start)
print('Train Score',train_sc,'test Score',test_sc)
# Out:
# Time taken for LGBM fit =  35.18166399002075
# Time taken for train data precition =  4.577259302139282
# Time taken for test data precition =  0.529304027557373
# Train Score 0.9832426574663836 test Score 0.9469947114279144
